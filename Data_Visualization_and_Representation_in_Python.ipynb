# %% [markdown]
# <a href="https://colab.research.google.com/github/AllEternal/Hamoye-Lessons-and-Quiz/blob/master/Data_Visualization_and_Representation_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url='https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'

# %%
fuel_data = pd.read_csv(url, error_bad_lines=False)
fuel_data.describe (include='all')
fuel_data.head()
# Out:
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
#
# [5 rows x 11 columns]

# %% [markdown]
# # Import Plotting Library

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
plt.figure(figsize=(7, 4))
plt.xticks(rotation=90)
fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'], 
                          'count': [7799, 84, 464, 110, 11354, 180, 95, 100, 8958]})
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %% [markdown]
# #Because of the extreme range of the values of the fuel unit, we can plot thr bar chat by taking the logarithms of the y axis as follows

# %%
g = sns.barplot(data=fuel_unit, x= 'unit', y='count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %% [markdown]
# # Select Sample of Dataset

# %%
sample_df = fuel_data.sample(n=50, random_state=4)

# %% [markdown]
# #Box Plot

# %%
sns.boxplot(x="fuel_type_code_pudl", y="utility_id_ferc1", 
            palette=["m", "g"], 
            data=fuel_data)

# %% [markdown]
# # KDE Plots

# %%
sns.kdeplot(sample_df['fuel_cost_per_unit_burned'], shade=True, color="b")

# %% [markdown]
# # Reg Plot

# %%
sns.regplot(x=sample_df["utility_id_ferc1"], y=sample_df["fuel_cost_per_mmbtu"], fit_reg=False)

# %%
C = fuel_data.corr()
sns.heatmap(C, xticklabels= C.columns, yticklabels=C.columns, annot=True)
